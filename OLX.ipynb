# %%
import pandas as pd 
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
# Get info of the page
page = requests.get('https://www.olx.pt/imoveis/apartamento-casa-a-venda/')
soup = BeautifulSoup(page.content, 'html.parser')

# %%
[type(item) for item in list(soup.children)][2]
# Out:
# bs4.element.Tag

# %%
html = list(soup.children)[2]

# %%
print(html.prettify())
# Out:
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
#    <title>
#     Apartamentos em Portugal
#    </title>
#    <link href="https://www.olx.pt/imoveis/apartamento-casa-a-venda/?page=2" rel="next"/>
#    <meta content="index, follow" name="robots"/>
#    <link href="https://www.olx.pt/imoveis/apartamento-casa-a-venda/" rel="canonical"/>
#    <link href="https://m.olx.pt/imoveis/apartamento-casa-a-venda/" media="only screen and (max-width: 640px)" rel="alternate"/>
#    <meta content="pt" http-equiv="Content-Language"/>
#    <meta content="Anúncios Classificados Apartamentos Portugal - Publique o seu anúncio de Apartamentos grátis no OLX. , Vende-se, Arrenda-se" name="description"/>
#    <meta content="Apartamentos em Portugal" property="og:title"/>
# ...

# %%
[item for item in soup.find_all('link')][0]
# Out:
# <link href="https://www.olx.pt/imoveis/apartamento-casa-a-venda/?page=2" rel="next"/>

# %%
[item for item in soup.find_all("a")][50]['href']
# Out:
# 'https://www.olx.pt/imoveis/apartamento-casa-a-venda/apartamentos-venda/'

# %%
links_to_request = [item['href'] for item in soup.find_all(class_="marginright5 link linkWithHash detailsLink")]
inside_link = BeautifulSoup(requests.get(links_to_request[0]).content
              , 'html.parser')

# %%
inside_link.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <title>Vende-se T3 Paranhos Combatentes/Salgueiros Paranhos • OLX Portugal</title>
# <meta content="index, follow" name="robots"/> <link href="https://www.olx.pt/anuncio/vende-se-t3-paranhos-combatentes-salgueiros-IDAWzyX.html" rel="canonical"/> <link href="https://m.olx.pt/anuncio/vende-se-t3-paranhos-combatentes-salgueiros-IDAWzyX.html" media="only screen and (max-width: 640px)" rel="alternate"/> <meta content="pt" http-equiv="Content-Language"/>
# <meta content="165.000 €: Vende-se T3 junto ao Metro dos Combatentes/Marquês/Salgueiros." name="description"/>
# <meta content="Vende-se T3 Paranhos Combatentes/Salgueiros" property="og:title"/>
# <meta content="165.000 €: Vende-se T3 junto ao Metro dos Combatentes/Marquês/Salgueiros." property="og:description"/>
# ...

# %%
title = inside_link.find_all('title')[0].get_text()

# %%
inside_link.find_all('title')[0].get_text()
link_of_house = inside_link.find_all('link')[0]['href']
price = inside_link.find_all(class_= 'xxxx-large not-arranged')[0].get_text()

# %%
linksss = [title, tipologia, freguesia, preço, area construção, link]

# %%
price-label
# Out:
# 'https://www.olx.pt/anuncio/vende-se-t3-paranhos-combatentes-salgueiros-IDAWzyX.html'
